# %%
import numpy as np
baseball = [[74, 180],
[72, 215],
[72, 210],
[73, 188],
[69, 176],
[69, 209],
[71, 200],
[76, 231],
[71, 180],
[73, 188],
[73, 180],
[74, 185],
[74, 160],
[69, 180],
[70, 185],
[73, 189],
[75, 185],
[78, 219],
[79, 230],
[76, 205],
[74, 230],
[76, 195],
[72, 180],
[71, 192],
[75, 225],
[77, 203],
[74, 195],
[73, 182],
[74, 188],
[78, 200],
[73, 180],
[75, 200],
[73, 200],
[75, 245],
[75, 240],
[74, 215],
[69, 185],
[71, 175],
[74, 199],
[73, 200],
[73, 215],
[76, 200],
[74, 205],
[74, 206],
[70, 186],
[72, 188],
[77, 220],
[74, 210],
[70, 195],
[73, 200],
[75, 200],
[76, 212],
[76, 224],
[78, 210],
[74, 205],
[74, 220],
[76, 195],
[77, 200],
[81, 260],
[78, 228],
[75, 270],
[77, 200],
[75, 210],
[76, 190],
[74, 220],
[72, 180],
[72, 205],
[75, 210],
[73, 220],
[73, 211],
[73, 200],
[70, 180],
[70, 190],
[70, 170],
[76, 230],
[68, 155],
[71, 185],
[72, 185],
[75, 200],
[75, 225],
[75, 225],
[75, 220],
[68, 160],
[74, 205],
[78, 235],
[71, 250],
[73, 210],
[76, 190],
[74, 160],
[74, 200],
[79, 205],
[75, 222],
[73, 195],
[76, 205],
[74, 220],
[74, 220],
[73, 170],
[72, 185],
[74, 195],
[73, 220],
[74, 230],
[72, 180],
[73, 220],
[69, 180],
[72, 180],
[73, 170],
[75, 210],
[75, 215],
[73, 200],
[72, 213],
[72, 180],
[76, 192],
[74, 235],
[72, 185],
[77, 235],
[74, 210],
[77, 222],
[75, 210],
[76, 230],
[80, 220],
[74, 180],
[74, 190],
[75, 200],
[78, 210],
[73, 194],
[73, 180],
[74, 190],
[75, 240],
[76, 200],
[71, 198],
[73, 200],
[74, 195],
[76, 210],
[76, 220],
[74, 190],
[73, 210],
[74, 225],
[70, 180],
[72, 185],
[73, 170],
[73, 185],
[73, 185],
[73, 180],
[71, 178],
[74, 175],
[74, 200],
[72, 204],
[74, 211],
[71, 190],
[74, 210],
[73, 190],
[75, 190],
[75, 185],
[79, 290],
[73, 175],
[75, 185],
[76, 200],
[74, 220],
[76, 170],
[78, 220],
[74, 190],
[76, 220],
[72, 205],
[74, 200],
[76, 250],
[74, 225],
[75, 215],
[78, 210],
[75, 215],
[72, 195],
[74, 200],
[72, 194],
[74, 220],
[70, 180],
[71, 180],
[70, 170],
[75, 195],
[71, 180],
[71, 170],
[73, 206],
[72, 205],
[71, 200],
[73, 225],
[72, 201],
[75, 225],
[74, 233],
[74, 180],
[75, 225],
[73, 180],
[77, 220],
[73, 180],
[76, 237],
[75, 215],
[74, 190],
[76, 235],
[75, 190],
[73, 180],
[71, 165],
[76, 195],
[75, 200]

]
# 1.Tạo 2D numpy array từ np_baseball từ baseball
np_baseball = np.array(baseball)
# 2.In ra giá trị của dòng thứ 50 trong np_baseball
print("2.Giá trị của dòng thứ 50:")
print(np_baseball[49])
# 3.Tạo numpy array np_weight với dữ liệu được lấy từ cột hai của np_baseball
np_weight = np_baseball[:, 1]
# 4.Tìm chiều cao của vận động viên thứ 124
height_124 = np_baseball[123, 0]  # Chú ý:index bắt đầu từ 0
print(f"4.Chiều cao của vận động viên thứ 124: {height_124} inch")
# 5.Tính chiều cao trung bình và cân nặng trung bình của các cầu thủ
avg_height = np.mean(np_baseball[:, 0])
avg_weight = np.mean(np_baseball[:, 1])
print(f"5.Chiều cao trung bình: {avg_height:.2f} inch")
print(f"5.Cân nặng trung bình: {avg_weight:.2f} pounds")
# 6.Phân tích mối tương quan giữa chiều cao và cân nặng
correlation = np.corrcoef(np_baseball[:, 0], np_baseball[:, 1])[0, 1]
print(f"6.Hệ số tương quan giữa chiều cao và cân nặng: {correlation:.4f}")
if correlation > 0.7:
    print("   Có tương quan mạnh giữa chiều cao và cân nặng")
elif correlation > 0.5:
    print("Có tương quan trung bình giữa chiều cao và cân nặng")
elif correlation > 0.3:
    print("Có tương quan yếu giữa chiều cao và cân nặng")
else:
    print("Hầu như không có tương quan giữa chiều cao và cân nặng")
# Out:
# 2.Giá trị của dòng thứ 50:
# [ 73 200]
# 4.Chiều cao của vận động viên thứ 124: 78 inch
# 5.Chiều cao trung bình: 73.83 inch
# 5.Cân nặng trung bình: 201.79 pounds
# 6.Hệ số tương quan giữa chiều cao và cân nặng: 0.5552
# Có tương quan trung bình giữa chiều cao và cân nặng
